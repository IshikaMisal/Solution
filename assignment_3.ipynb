# %%
a = input("Enter ur name:")
b = input("enter ur DOB(IN DD/MM/YY):")
c = input("enter ur gender(M/F/O):")
d = b[0:2]
e = b[2:4]

if e==10:
  if (d<22):
    zodic_sign="sagittarius" 
  else:
      "capricon"
elif e==1:
  if(d<20):
    zodic_sign="capricon"
  else:
      "aquarius"
elif e==2:
  if(d<19):
    zodic_sign="aquarius"
  else:
      "pisces"
elif e==3:
  if(d<21):
    zodic_sign="pisces"
  else:
      "aries"
elif e==4:
  if(d<20):
    zodic_sign="aries"
  else:
      "taurus"
elif e==5:
  if(d<21):
    zodic_sign="taurus"
  else:
    "gemini"
elif e==6:
  if(d<21):
    zodic_sign="gemini"
  else:
    "cancer"
elif e==7:
  if(d<23):
    zodic_sign="cancer"
  else:
    "leo"
elif e==8:
  if(d<23):
    zodic_sign="leo"
  else:
    "virgo"
elif e==9:
  if(d<23):
    zodic_sign="virgo"
  else:
    "libra"
elif e==10:
  if(d<23):
    zodic_sign="libra"
  else:
      "scorpio"
elif e==11:
  if(d<22):
    zodic_sign="scorpio"
  else:
    "sagittarius"
print("your astrological sign is:", zodic_sign)

# %%
a = input("laws of thermodynamics (select 1,2,3):")
if a==1:
  print("The first law, also known as Law of Conservation of Energy, states that energy cannot be created or destroyed in an isolated system.")
elif a==2:
  print("The second law of thermodynamics states that the entropy of any isolated system always increases.")
elif a==3:
  print("The third law of thermodynamics states that the entropy of a system approaches a constant value as the temperature approaches absolute zero")
else:
  print("invalid")

# %%
a = input("select any one from the following options :\n1.communism \n2.democracy \n3.marxism \n4.socialism \n>")
b = input("select religion: \n1.jainism \n2.buddhism \n3.hinduism \n4.sikhism \n5.christianity")
if (a==democracy):
  print("principles of democracy:\n1.The principle of due process of law.\n2. The principle of openness\n3. The principle of involvement\n4. The principle of public debate\n5. The principle of public hearing")
if (a==communism):
  print("principles of communism:\n1.Communism is the doctrine of the conditions of the liberation of the proletariat\n2.The proletariat is that class in society which lives entirely from the sale of its labor and does not draw profit from any kind of capital; whose weal and woe, whose life and death, whose sole existence depends on the demand for labor – hence, on the changing state of business, on the vagaries of unbridled competition. The proletariat, or the class of proletarians, is, in a word, the working class of the 19th century.\n3.The working classes have always, according to the different stages of development of society, lived in different circumstances and had different relations to the owning and ruling classes.")
if (a==marxism):
  print("principles of marxism:\n1) The Means or Mode of Production\n2.Historical Materialism\n3.Hegemony\n4.Capitalism, Profit And Labor\n5.Ideology")
if (a==socialism):
    print("principples of socialism:\n1.The taking of political power\n2.Utopian socialism\n3.Christian socialism\n4.Anarchism\n5.Market Socialism")
else:
  print("invalid")
  
if (b==jainism):
  print("fundamentals of jainism are:\n1.Non-violence (Ahimsa)\n2.Non-violence (Ahimsa)\n3.Non-stealing (Achaurya)\n4.Celibacy (Brahmacharya)\n5.Non-Possessiveness (Aparigraha)")
if (b==buddhism):
  print("Five Precepts of Buddhism are:\n1.undertake to observe the rule\n2.to abstain from taking life\n3. to abstain from taking what is not given\n4.to abstain from false speech\n5.to abstain from intoxicants as tending to cloud the mind")
if (b==hindisim):
  print("principles of hinduism are:\n1.God Exists\n2.All Human Beings Are Divine\n3.Unity of Existence.\n4.Religious Harmony\n5.Knowledge of 3 Gs")
if (b==sikhism):
  print("Five Principles of Sikhism:\n1.Nam Japna~Thanks, saying the word...\n2.Dharam de Kirat~Honest living\n3.Wand ke Shakna~Share what we consume\n4.Bhanna Mannanna~Acceptance of the present moment\n5.Sarbat Ka Bhalla~Help for all.")
if (b==socialism):
  print("Principles of Socialism:\n1.Guild socialism\n2.Utopian socialism\n3.Christian socialism\n4.Anarchism\n5.State socialism")
else:
  print("invalid")
